# %%
import json
import pandas as pd

# %%
with open('data/original_nations.json') as json_file:  
    data = json.load(json_file)

# %%
type(data),len(data)
# Out:
# (list, 180)

# %%
data[1].keys()
#'lifeExpectancy', 'population', 'income' = [[year, val]*]
# Out:
# dict_keys(['lifeExpectancy', 'region', 'population', 'name', 'income'])

# %%
regions = set()
country_region_dict={}
for i in range(len(data)):
    
    curr = data[i]
    country_region_dict[curr['name']]=curr['region']
    regions.add(curr['region'])

# %%
regions
# Out:
# {'America',
#  'East Asia & Pacific',
#  'Europe & Central Asia',
#  'Middle East & North Africa',
#  'South Asia',
#  'Sub-Saharan Africa'}

# %%
# dictionary for every country
# name, region from dict

# %%
import os
filenames = os.listdir('csvs/')
filenames
# Out:
# ['mean_years_in_school_men_25_years_and_older.csv',
#  'co2_emissions_tonnes_per_person.csv',
#  'income_per_person_gdppercapita_ppp_inflation_adjusted.csv',
#  'life_expectancy_years.csv',
#  'mean_years_in_school_women_25_years_and_older.csv',
#  'population_total.csv',
#  'mean_years_in_school_women_15_to_24_years.csv',
#  'mean_years_in_school_men_15_to_24_years.csv']

# %%
df = pd.read_csv('csvs/co2_emissions_tonnes_per_person.csv', index_col='country')
df.columns = df.columns.astype(int)
df.head()
# Out:
#              1800  1801  1802  1803  1804  1805  1806  1807  1808  1809  \
# country
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Andorra       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#              ...      2005    2006    2007   2008   2009   2010   2011  2012  \
# country      ...
# Afghanistan  ...    0.0529  0.0637  0.0854  0.154  0.242  0.294  0.412  0.35
# Albania      ...    1.3800  1.2800  1.3000  1.460  1.480  1.560  1.790  1.68
# Algeria      ...    3.2200  2.9900  3.1900  3.160  3.420  3.300  3.290  3.46
# Andorra      ...    7.3000  6.7500  6.5200  6.430  6.120  6.120  5.870  5.92
# Angola       ...    0.9800  1.1000  1.2000  1.180  1.230  1.240  1.250  1.33
#
#               2013   2014
# country
# ...

# %%
df.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100],
#            dtype='int64', length=301)

# %%
df = df.drop(columns=[i for i in range(1800,1930) ])

# %%
df.head()
# Out:
#                1930    1931    1932     1933     1934    1935     1936  \
# country
# Afghanistan     NaN     NaN     NaN      NaN      NaN     NaN      NaN
# Albania         NaN     NaN     NaN  0.00711  0.00707  0.0176  0.12200
# Algeria      0.0123  0.0142  0.0161  0.01690  0.01930  0.0180  0.00692
# Andorra         NaN     NaN     NaN      NaN      NaN     NaN      NaN
# Angola          NaN     NaN     NaN      NaN      NaN     NaN      NaN
#
#                 1937     1938    1939  ...      2005    2006    2007   2008  \
# country                                ...
# Afghanistan      NaN      NaN     NaN  ...    0.0529  0.0637  0.0854  0.154
# Albania      0.27900  0.32200  0.3920  ...    1.3800  1.2800  1.3000  1.460
# Algeria      0.00928  0.00434  0.0209  ...    3.2200  2.9900  3.1900  3.160
# Andorra          NaN      NaN     NaN  ...    7.3000  6.7500  6.5200  6.430
# Angola           NaN      NaN     NaN  ...    0.9800  1.1000  1.2000  1.180
#
# ...

# %%
df.head()
# Out:
#                1930    1931    1932     1933     1934    1935     1936  \
# country
# Afghanistan     NaN     NaN     NaN      NaN      NaN     NaN      NaN
# Albania         NaN     NaN     NaN  0.00711  0.00707  0.0176  0.12200
# Algeria      0.0123  0.0142  0.0161  0.01690  0.01930  0.0180  0.00692
# Andorra         NaN     NaN     NaN      NaN      NaN     NaN      NaN
# Angola          NaN     NaN     NaN      NaN      NaN     NaN      NaN
#
#                 1937     1938    1939  ...      2005    2006    2007   2008  \
# country                                ...
# Afghanistan      NaN      NaN     NaN  ...    0.0529  0.0637  0.0854  0.154
# Albania      0.27900  0.32200  0.3920  ...    1.3800  1.2800  1.3000  1.460
# Algeria      0.00928  0.00434  0.0209  ...    3.2200  2.9900  3.1900  3.160
# Andorra          NaN      NaN     NaN  ...    7.3000  6.7500  6.5200  6.430
# Angola           NaN      NaN     NaN  ...    0.9800  1.1000  1.2000  1.180
#
# ...

# %%
# men_df = pd.read_csv('csvs/mean_years_in_school_men_15_to_24_years.csv', index_col='country')
# women_df = df = pd.read_csv('csvs/mean_years_in_school_women_15_to_24_years.csv', index_col='country')

# df_concat = pd.concat((men_df, women_df))
# by_row_index = df_concat.groupby(df_concat.index)
# df_means = by_row_index.mean()

# df_means.head()

# %%
dict(df.loc['Angola'])
# Out:
# {1930: nan,
#  1931: nan,
#  1932: nan,
#  1933: nan,
#  1934: nan,
#  1935: nan,
#  1936: nan,
#  1937: nan,
#  1938: nan,
#  1939: nan,
#  1940: nan,
#  1941: nan,
#  1942: nan,
#  1943: nan,
#  1944: nan,
#  1945: nan,
#  1946: nan,
#  1947: nan,
#  1948: nan,
#  1949: nan,
#  1950: 0.0411,
#  1951: 0.0535,
#  1952: 0.0653,
#  1953: 0.0562,
#  1954: 0.0696,
#  1955: 0.081,
#  1956: 0.0962,
#  1957: 0.11599999999999999,
#  1958: 0.109,
#  1959: 0.11199999999999999,
#  1960: 0.0975,
#  1961: 0.079,
#  1962: 0.201,
#  1963: 0.193,
#  1964: 0.201,
#  1965: 0.192,
#  1966: 0.24600000000000002,
#  1967: 0.155,
#  1968: 0.256,
#  1969: 0.42,
#  1970: 0.529,
#  1971: 0.49200000000000005,
#  1972: 0.635,
#  1973: 0.6709999999999999,
#  1974: 0.652,
#  1975: 0.575,
#  1976: 0.41600000000000004,
#  1977: 0.435,
#  1978: 0.6459999999999999,
#  1979: 0.637,
#  1980: 0.599,
#  1981: 0.5710000000000001,
#  1982: 0.485,
#  1983: 0.515,
#  1984: 0.48700000000000004,
#  1985: 0.44299999999999995,
# ...

# %%
#df = df_means
new_data=[]
df =df.fillna(0)
df.columns = df.columns.astype(int)

minv,maxv=999999,-999999

for i in range(len(data)):
    country_name = data[i]['name']
    if country_name in df.index and country_name !='Brunei' :
        new_data.append(data[i])
        curr_dict = dict(df.loc[country_name])
        curr_list = []
        for k,v in curr_dict.items():
            minv = min(minv,v)
            maxv=max(maxv,v)
            curr_list.append([k,v])
        new_data[-1]["co2_emissions_tonnes_per_person"] = curr_list

# %%
new_data[0].keys()
# Out:
# dict_keys(['lifeExpectancy', 'income', 'co2_emissions_tonnes_per_person', 'region', 'life_expectancy_years', 'name', 'mean_years_in_school_15_to_24_years', 'population'])

# %%
len(new_data),minv,maxv
# Out:
# (161, 0.0, 101.0)

# %%
new_data[0]
# Out:
# {'co2_emissions_tonnes_per_person': [[1930, 0.0],
#   [1931, 0.0],
#   [1932, 0.0],
#   [1933, 0.0],
#   [1934, 0.0],
#   [1935, 0.0],
#   [1936, 0.0],
#   [1937, 0.0],
#   [1938, 0.0],
#   [1939, 0.0],
#   [1940, 0.0],
#   [1941, 0.0],
#   [1942, 0.0],
#   [1943, 0.0],
#   [1944, 0.0],
#   [1945, 0.0],
#   [1946, 0.0],
#   [1947, 0.0],
#   [1948, 0.0],
#   [1949, 0.0],
#   [1950, 0.0411],
#   [1951, 0.0535],
#   [1952, 0.0653],
#   [1953, 0.0562],
#   [1954, 0.0696],
#   [1955, 0.081],
#   [1956, 0.0962],
#   [1957, 0.11599999999999999],
#   [1958, 0.109],
#   [1959, 0.11199999999999999],
#   [1960, 0.0975],
#   [1961, 0.079],
#   [1962, 0.201],
#   [1963, 0.193],
#   [1964, 0.201],
#   [1965, 0.192],
#   [1966, 0.24600000000000002],
#   [1967, 0.155],
#   [1968, 0.256],
#   [1969, 0.42],
#   [1970, 0.529],
#   [1971, 0.49200000000000005],
#   [1972, 0.635],
#   [1973, 0.6709999999999999],
#   [1974, 0.652],
#   [1975, 0.575],
#   [1976, 0.41600000000000004],
#   [1977, 0.435],
# ...

# %%
with open('data/new_nations.json', 'w') as fout:
    json.dump(new_data, fout)
